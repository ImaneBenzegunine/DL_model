# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys
import os
import re

# %%
scripts_path = os.path.abspath(os.path.join(os.getcwd(), '../Scripts'))
sys.path.append(scripts_path)

# %%
from path import PATH_AUTO_CSV, PATH_AUTO_XLSX

# %% [markdown]
# ## 1 - Import Data

# %%
data = pd.read_csv(PATH_AUTO_CSV)

# %%
data2 = data.copy()

# %%
data2.shape
# Out:
# (10655, 16)

# %%
data2.head()
# Out:
#                   CarName                             carDetails  \
# 0     Mercedes-Benz A 180  d 2019 zetelverwarming camera GPS PTS
# 1   Mercedes-Benz GLA 180                              180 Urban
# 2     Mercedes-Benz A 180        BE ~ Led ~ PDC ~ Navi ~ TopDeal
# 3  Mercedes-Benz E 53 AMG          Berline AMG 53 Hybrid 4MATIC+
# 4   Mercedes-Benz GLC 250                     4-Matic *AMG pack*
#
#           CarPrice               Etat   Milieage       Transmission    Annee  \
# 0      € 16 900,-5           Bon prix  84 100 km     Boîte manuelle  09/2019
# 1      € 17 950,-5           Bon prix  40 671 km     Boîte manuelle  03/2017
# 2      € 15 990,-5           Bon prix  69 636 km     Boîte manuelle  07/2018
# 3  € 109 990,-1, 5  Pas d'information  11 998 km                  -  07/2024
# 4   € 31 500,-1, 5           Bon prix  71 300 km  Boîte automatique  08/2019
#
#             Carburant     CarPuissance     CarVendeur  Portes  seats  \
# 0              Diesel   85 kW (116 CH)  Professionnel     5.0    5.0
# 1             Essence   90 kW (122 CH)  Professionnel     5.0    5.0
# 2             Essence   90 kW (122 CH)  Professionnel     5.0    5.0
# 3  Electrique/Essence  430 kW (585 CH)  Professionnel     5.0    4.0
# 4             Essence  155 kW (211 CH)  Professionnel     5.0    5.0
#
#                                              Options  \
# 0  85 kW (116 CH) Boîte manuelle 1 461 cm³ 6 4 1 ...
# 1  90 kW (122 CH) Boîte manuelle 1 595 cm³ 6 4 1 ...
# 2  90 kW (122 CH) Boîte manuelle 1 595 cm³ 6 4 1 ...
# 3     430 kW (585 CH) Boîte automatique 2 999 cm³ 6
# 4  155 kW (211 CH) Boîte automatique 1 991 cm³ 9 ...
#
#                              ConsommationEnergétique  \
# 0  Euro 6d Diesel 3,8 l/100 km (mixte) 106 g/km (...
# 1  Euro 6 Essence 5,7 l/100 km (mixte) 133 g/km (...
# 2  Euro 6b Essence 5,2 l/100 km (mixte) 120 g/km ...
# 3                        Électrique 22 g/km (mixte)
# 4  Euro 6d Super 95 7,1 l/100 km (mixte) 162 g/km...
#
#                           CouleurGarnissageIntérieur  \
# 0  Bleu Denimblauw metallic Métallisé Noir Cuir p...
# 1                  Gris Métallisé Noir Cuir partiel
# 2                          Argent Noir Cuir partiel
# 3                                         Noir Noir
# 4                          Bleu Métallisé Noir Cuir
#
#                                                 link
# 0  https://www.autoscout24.be/fr/offres/mercedes-...
# 1  https://www.autoscout24.be/fr/offres/mercedes-...
# 2  https://www.autoscout24.be/fr/offres/mercedes-...
# 3  https://www.autoscout24.be/fr/offres/mercedes-...
# 4  https://www.autoscout24.be/fr/offres/mercedes-...

# %% [markdown]
# ## 2 - EDA

# %% [markdown]
# #### 2 - 1 Nan Values

# %%
data2.isna().sum()
# Out:
# CarName                         0
# carDetails                    242
# CarPrice                        0
# Etat                            0
# Milieage                        0
# Transmission                    0
# Annee                           0
# Carburant                       0
# CarPuissance                    0
# CarVendeur                      0
# Portes                        691
# seats                         420
# Options                         0
# ConsommationEnergétique         0
# CouleurGarnissageIntérieur      0
# link                            0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655 entries, 0 to 10654
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CarName                     10655 non-null  object
#  1   carDetails                  10413 non-null  object
#  2   CarPrice                    10655 non-null  object
#  3   Etat                        10655 non-null  object
#  4   Milieage                    10655 non-null  object
#  5   Transmission                10655 non-null  object
#  6   Annee                       10655 non-null  object
#  7   Carburant                   10655 non-null  object
#  8   CarPuissance                10655 non-null  object
#  9   CarVendeur                  10655 non-null  object
#  10  Portes                      9964 non-null   float64
#  11  seats                       10235 non-null  float64
#  12  Options                     10655 non-null  object
#  13  ConsommationEnergétique     10655 non-null  object
#  14  CouleurGarnissageIntérieur  10655 non-null  object
#  15  link                        10655 non-null  object
# dtypes: float64(2), object(14)
# memory usage: 1.3+ MB

# %%
sns.heatmap(data2.isna())
# Out:
# <Axes: >

# %% [markdown]
# #### 2 - 2 data-info

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655 entries, 0 to 10654
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   CarName                     10655 non-null  object
#  1   carDetails                  10413 non-null  object
#  2   CarPrice                    10655 non-null  object
#  3   Etat                        10655 non-null  object
#  4   Milieage                    10655 non-null  object
#  5   Transmission                10655 non-null  object
#  6   Annee                       10655 non-null  object
#  7   Carburant                   10655 non-null  object
#  8   CarPuissance                10655 non-null  object
#  9   CarVendeur                  10655 non-null  object
#  10  Portes                      9964 non-null   float64
#  11  seats                       10235 non-null  float64
#  12  Options                     10655 non-null  object
#  13  ConsommationEnergétique     10655 non-null  object
#  14  CouleurGarnissageIntérieur  10655 non-null  object
#  15  link                        10655 non-null  object
# dtypes: float64(2), object(14)
# memory usage: 1.3+ MB

# %%
def separer_marque_modele(x):
    x = x.split(" ")[0]
    if "-" in x :
        x = x.split("-")[0]
        return x
    return x.split(" ")[0]

# %%
def extract_model(x):
    return " ".join(x.split()[1:])

# %%
data2["Modele"] = data2["CarName"].apply(extract_model)

# %%
data2["Modele"].unique()
# Out:
# array(['A 180', 'GLA 180', 'E 53 AMG', 'GLC 250', 'GLA 250', 'C 220',
#        'CLA 200', 'E 200', 'ML 250', 'E 43 AMG', 'C 180', 'CLS 450',
#        'B 180', 'GLC 300', 'C 63 AMG', 'S 350', 'E 220', 'CLA 180',
#        'GLA 200', 'C 200', 'GLB 180', 'A 250', 'EQB 250', 'S 300',
#        'E 300', 'EQC 400', 'SLK 200', 'A 160', 'GLC 220', 'GLC 200',
#        'GLE 400', 'E 400', 'GLC 43 AMG', 'CLA 250', 'Vito', 'CLC',
#        'C 160', 'A 45 AMG', 'GLB 200', 'B 200', 'A 150', 'GLA 45 AMG',
#        'CLS 220', 'S 400', 'GLE 350', 'SL 43 AMG', 'EQA', 'C 300',
#        'AMG GT', 'A 200', 'CLE 200', 'EQA 250', 'S 600', 'EQS', 'V 250',
#        'CLA 35 AMG', '', 'GLC 400', 'C 43 AMG', 'GLE 300', 'S 580',
#        'GLS 400', 'V 300', 'X 350', 'EQE SUV', 'EQE 300', 'S 500',
#        'A 35 AMG', 'GLE 53 AMG', 'G 63 AMG', 'G 500', 'GLE 43 AMG',
#        'GLS 63 AMG', 'GLE 450', 'E 250', 'Maybach S-Klasse', 'GL 420',
#        'GLA 35 AMG', 'SL 450', 'CLE 300', 'GLC 350', 'Citan', '300',
#        'SL 280', 'Marco Polo', 'SL 63 AMG', 'CLE 220', '316', 'XM', '118',
#        'Golf Variant', 'Scirocco', 'Tiguan Allspace', 'Polo', 'T-Roc',
#        'Fox', 'Golf', 'New Beetle', 'up!', 'ID. Buzz', 'Tiguan',
#        'T-Cross', 'Caddy', 'Touran', 'Golf GTI', 'Passat',
#        'Golf Sportsvan', 'ID.3', 'Sharan', 'Transporter',
#        'Passat Variant', 'Crafter', 'Arteon', 'T6 Multivan', 'e-Golf',
#        'Touareg', 'Passat CC', 'Taigo', 'Beetle', 'T7 Multivan', 'Bora',
#        'Golf R', 'Polo GTI', 'ID.4', 'Golf GTE', 'ID.5', 'T6.1 Caravelle',
#        'Amarok', 'Golf Cabriolet', 'S5', 'A6', 'A3', 'Q7', 'A4', 'Q3',
#        'A5', 'Q2', 'A1', 'Q5', 'Q4 e-tron', 'e-tron GT', 'Q8', 'e-tron',
#        'RS Q3', 'RS6', 'TT', 'A8', 'S8', 'S6', 'S3', 'A7', 'A4 allroad',
#        'RS3', 'RS7', 'R8', 'S7', 'S4', 'Q8 e-tron', 'RS5', 'RS4',
#        'RS e-tron GT', 'TT RS', 'Auris', 'Avensis', 'C-HR', 'GR86',
#        'Aygo X', 'Yaris', 'Aygo', 'Verso-S', 'Proace', 'RAV 4', 'Corolla',
#        'Verso', 'Yaris Cross', 'Proace City', 'Prius', 'Corolla Cross',
#        'Mirai', 'Land Cruiser', 'bZ4X', 'Highlander', '4-Runner', 'MR 2',
#        'Corolla Verso', 'Camry', 'Previa', 'Hilux', 'FJ40', 'Hiace', 'iQ',
#        'Starlet', 'Mark II', 'Cooper D', 'One', 'Cooper',
#        'Cooper S Countryman', 'Cooper SE Countryman', 'John Cooper Works',
#        'Cooper S', 'One Countryman', 'Cooper Countryman',
#        'Cooper D Countryman', 'Cooper SE', 'Cooper Cabrio',
#        'Cooper S Cabrio', 'One D', 'John Cooper Works Clubman',
#        'One D Clubman', 'Cooper Clubman', 'Countryman C',
#        'John Cooper Works Countryman', 'Cooper S Clubman',
#        'Cooper SD Cabrio', 'Cooper SD Coupe', 'Cooper D Cabrio',
#        'Countryman E', 'Cooper SD Clubman', 'Cooper SD Countryman',
#        'One Clubman', 'Cooper D Clubman', '1300', 'Countryman S All4',
#        'Cooper SD Paceman', 'Cooper Roadster', 'One Cabrio',
#        'John Cooper Works Roadster', 'John Cooper Works Cabrio',
#        'Cooper Coupe', 'Taycan', 'Boxster', '718', 'Panamera', 'Macan',
#        'Cayman', '997', 'Cayenne', '991', '911', '992', '944', '996',
#        '964', '718 Spyder', '930', '993', 'Targa', '968', '914', '928',
#        '550', 'Captur', 'Clio', 'Scenic', 'Twingo', 'Grand Scenic',
#        'Kadjar', 'Kangoo', 'Megane', 'Espace', 'R 5', 'Arkana',
#        'Talisman', 'Wind', 'Koleos', 'Vel Satis', 'Austral', 'Latitude',
#        'Trafic', 'Master', 'Rafale', 'ZOE', 'Modus', 'Express', 'Laguna',
#        'Megane E-Tech', 'Symbioz', 'Grand Espace', 'R 4', '208', '508',
#        '2008', 'Partner', '3008', '5008', '207', '308', '108', 'Rifter',
#        'RCZ', '307', 'Traveller', '206', '408', '205', 'e-2008',
#        'e-Rifter', 'Expert', 'Boxer', 'Bipper', '807', 'Ka/Ka+', 'C-Max',
#        'Kuga', 'Fiesta', 'Focus', 'Mondeo', 'Transit Custom', 'EcoSport',
#        'Puma', 'Grand C-Max', 'B-Max', 'Mustang Mach-E', 'S-Max',
#        'Mustang', 'Ranger', 'Tourneo Courier', 'Tourneo Custom', 'F 150',
#        'Tourneo Connect', 'Tourneo', 'Edge', 'Explorer', 'GT',
#        'Transit Connect', 'Bronco', 'Ranger Raptor', 'Galaxy',
#        'Transit Courier', 'Transit', 'Focus C-Max', 'E-Transit',
#        'Gran Torino', 'Punto EVO', '595', '595 Competizione', '595 Pista',
#        '595 Turismo', '595C', '500', '695', '695C', '500e', '500C',
#        '124 Spider', 'Grande Punto', 'Ateca', 'Leon', 'Ibiza', 'Mii',
#        'Arona', 'Alhambra', 'Toledo', 'Altea XL', 'Cordoba', 'Altea',
#        'Tarraco', 'Exeo', 'Arosa', 'Leon e-Hybrid', 'Corsa',
#        'Crossland X', 'Astra', 'Mokka', 'Grandland X', 'Zafira',
#        'Crossland', 'Ampera', 'Zafira Tourer', 'Insignia', 'Adam',
#        'Combo', 'Meriva', 'Mokka X', 'Grandland', 'Mokka-E', 'Antara',
#        'Vivaro', 'Cascada', 'Zafira Life', 'Combo Life', 'Movano',
#        'Corsa-e', 'Karl', 'Kadett', 'Frontera', 'Vectra', 'Agila',
#        'Micra', 'Qashqai', 'Leaf', 'X-Trail', 'Navara', 'Juke', 'NV200',
#        'Townstar', 'NV400', 'Note', 'Ariya', 'Primastar', 'Interstar',
#        'NV300', '350Z', 'GT-R', 'Pixo', 'Pulsar', 'Qashqai+2', 'Almera',
#        'Primera', '200 SX', 'Maxima', 'Skyline', 'Space Star', 'Lancer',
#        'Outlander', 'ASX', 'Eclipse Cross', 'Canter', 'L200', 'Carisma',
#        'Pajero', 'Colt', 'Attrage', 'Grandis', 'Galant', 'Eclipse',
#        '3000 GT', 'I-MiEV', 'Montero', 'Pajero Sport', '323', '3',
#        'CX-60', 'CX-30', '6', '5', 'MX-30', 'CX-5', '2', 'CX-3', 'MX-5',
#        'RX-8', 'CX-7', 'CX-9', 'B Series', 'Xedos', '626', 'Demio', '121',
#        'RX-7', 'CX-80', 'Romeo Stelvio', 'Romeo Giulietta', 'Romeo 159',
#        'Romeo Giulia', 'Romeo Tonale', 'Romeo MiTo', 'Romeo Alfa 6',
#        'Romeo Spider', 'Romeo GT', 'Romeo', 'Romeo 147', 'Romeo Alfetta',
#        'Romeo 164', 'Romeo GTV', 'Romeo 156', 'Romeo 33', 'Romeo Brera',
#        'Romeo Junior', 'Romeo 2000', 'Romeo 166', 'Romeo 75',
#        'Romeo 1750', 'Romeo Alfasud', 'Romeo 8C', 'Romeo 4C',
#        'Continental GT', 'Continental', 'Bentayga', 'Mulsanne',
#        'Continental GTC', 'Turbo R', 'Flying Spur', 'Arnage', 'S2',
#        'Brooklands', 'Azure', 'S1', 'Escalade', 'BLS', 'STS', 'CT4',
#        'ATS', 'XT4', 'Eldorado', 'Deville', 'Fleetwood', 'Seville', 'CT6',
#        'Series 62', 'Spark', 'Suburban', 'Silverado', 'Camaro',
#        'Corvette', 'Kalos', 'Aveo', 'Cruze', 'Matiz', 'Captiva',
#        'Orlando', 'Nubira', 'Malibu', 'Trax', 'El Camino', 'Caprice',
#        'Avalanche', 'Lacetti', 'Astro', 'Epica', 'Corsica', 'Beretta',
#        'Monte Carlo', 'Trans Sport', 'Chevy Van', 'Blazer', 'SSR',
#        'Tacuma', 'Impala', 'K30', 'C1500', 'Chevelle', 'Bel Air', 'C1',
#        'Berlingo', 'C3', 'C4', 'C4 SpaceTourer', 'Grand C4 Picasso',
#        'Grand C4 SpaceTourer', 'SAXO', 'C3 Aircross', 'C5', 'C4 Cactus',
#        'C5 Aircross', 'C5 X', 'Spacetourer', 'Jumpy', 'Ami', 'Jumper',
#        'C6', 'DS', 'C3 Picasso', 'C4 Picasso', 'DS3', 'DS5', 'E-C4 X',
#        'AX', 'DS4', 'Xsara Picasso', 'C4 Aircross', 'C-Elysée', 'C15',
#        'C2', 'C8', 'C-Crosser', 'Formentor', 'Born', 'Formentor VZ5',
#        'Terramar', 'Tavascan', 'Jogger', 'Sandero', 'Duster', 'Dokker',
#        'Spring', 'Lodgy', 'Logan', '1310', 'GTC4 Lusso', '488', '458',
#        '612', 'California', 'SF90 Stradale', 'Roma', 'F430',
#        'SF90 Spider', '296 GTB', '456', 'F8 Tributo', 'F355', 'F12',
#        'Portofino', '296', 'Purosangue', '812', '360', '430 Scuderia',
#        'F8 Spider', 'Mondial', '599', 'FF', 'Daytona', '348', '512',
#        '246', 'Testarossa', 'Superamerica', '400', '328',
#        'Scuderia Spider 16M', '250', '575', '365', '330',
#        'Automobiles DS 7 Crossback', 'Automobiles DS 3 Crossback',
#        'Automobiles DS 9', 'Automobiles DS 4', 'Automobiles DS 5',
#        'Automobiles DS 3', 'Automobiles DS 7',
#        'Automobiles DS 4 Crossback', 'Punto Evo', 'Tipo', 'Panda', '500X',
#        '500L', 'Ducato', 'Talento', 'Doblo', 'Scudo', 'Punto',
#        '500 Abarth', 'Barchetta', 'Freemont', 'E-Doblo', '600', 'Fiorino',
#        'Qubo', 'Bravo', 'Idea', 'Multipla', 'Coupe', 'Stilo', 'Seicento',
#        'Swift', '318', 'Rover Discovery Sport', '114', 'V40', '9-3',
#        'Q50', 'Jetta', 'Compass', 'Octavia', 'Superb',
#        'Rover Range Rover Sport', 'Rover Range Rover Evoque', '520',
#        'Renegade', 'X1', 'C30', 'Carens', 'M4', 'X3', 'Rover Defender',
#        'Sportage', 'J7', 'Model Y', '216', 'XE', 'Jimny', 'XC60',
#        'F-Pace', 'KONA', '116', 'XC40', '530', 'Stonic', 'Kodiaq',
#        'Fabia', 'X5', '430', 'UX 300e', 'i30', '420', 'SX4 S-Cross',
#        '325', '135', 'Getz', 'Karoq', 'S60', 'X2', 'Picanto', 'V60', 'M2',
#        'TUCSON', 'ZS', '218', "Ceed / cee'd", '518', '320', 'CR-V', 'i20',
#        'Scala', 'X4', 'Rover Range Rover Velar', 'Civic', '730',
#        'Golf GTD', 'T6 Caravelle', 'T4 Multivan'], dtype=object)

# %% [markdown]
# #### 2 - 3 Data Cleaning

# %% [markdown]
# ##### 2 - 3.1 FullCareName

# %% [markdown]
# ##### 2 - 3.2 CarPrice

# %%
def extractPrice(text):
    cleaned_text = re.sub(r'[^\d]', '', text)  
    return int(cleaned_text[:-1])

# %%
data2['Price'] = data2['CarPrice'].apply(extractPrice)

# %% [markdown]
# ##### 2 - 3.3 CarPrice

# %%
data2['Price'] = data2['CarPrice'].apply(extractPrice)

# %%
price_mapping = {
    "Très bon prix": 3,
    "Bon prix": 2,
    "Prix correct": 1,
    "Pas d'information": 0
}

# %%
data2['etatCategory'] = data2['Etat'].map(price_mapping)

# %% [markdown]
# ##### 2 - 3.4 Milieage

# %%
def extract_kilometrage(text):
    return int(re.sub(r'[^\d]', '', text))

# %%
data2['Milieage']
# Out:
# 0      250000
# 1       27500
# 2       73409
# 3      142000
# 4       22700
#         ...
# 392     31820
# 393    118226
# 394     86802
# 395     50163
# 396     43968
# Name: Milieage, Length: 397, dtype: int64

# %%
data2['Milieage'] = data2['Milieage'].apply(extract_kilometrage)

# %% [markdown]
# ##### 2 - 3.5 Annee

# %%
data2['Annee'].unique()
# Out:
# array(['03/2010', '09/2021', '02/2006', '07/2015', '09/2023', '07/2023',
#        '08/2015', '03/2011', '05/2013', '10/2024', '10/2015', '11/2012',
#        '04/2018', '12/2014', '12/2008', '11/2017', '02/2016', '08/2021',
#        '09/2015', '02/2017', '02/2014', '01/2013', '04/2013', '04/2015',
#        '01/2019', '01/2012', '03/2015', '07/2013', '02/2012', '12/2015',
#        '12/2009', '05/2009', '07/2012', '01/2025', '07/2020', '01/2020',
#        '06/2018', '08/2016', '01/2011', '12/2020', '03/2017', '02/2011',
#        '09/2016', '08/2018', '01/2023', '06/2005', '12/2011', '10/2012',
#        '04/2017', '05/2019', '03/2016', '01/2015', '06/2015', '03/2021',
#        '09/2020', '06/2020', '03/2020', '11/2024', '06/2016', '10/2022',
#        '09/2008', '02/2020', '01/2017', '09/2017', '07/2022', '10/2023',
#        '04/2019', '02/2018', '04/2016', '08/2013', '01/2022', '04/2012',
#        '07/2019', '05/2021', '11/2016', '08/2017', '12/2016', '03/2014',
#        '01/2021', '07/2010', '12/2017', '05/2016', '06/2024', '05/2012',
#        '11/2022', '01/2018', '03/2013', '10/2020', '12/2019', '03/2018',
#        '04/2023', '03/2024', '04/2014', '05/2022', '05/2015', '01/2014',
#        '02/2023', '06/2019', '04/2008', '01/2016', '11/2021', '11/2018',
#        '12/2018', '11/2020', '10/2019', '06/2017', '11/2009', '11/2015',
#        '03/2012', '06/2012', '04/2011', '04/2009', '02/2024', '02/2009',
#        '08/2020', '07/2003', '09/2014', '12/2012', '09/2019', '10/2016',
#        '02/2019', '04/2022', '03/2019', '04/2020', '09/2007', '08/2019',
#        '10/2017', '03/2023', '05/2014', '07/2014', '07/2021', '03/2006',
#        '07/2008', '05/2017', '01/2010', '03/2022', '11/2023', '06/2022',
#        '10/2018', '-', '02/2021', '04/2024', '02/2022', '05/2024',
#        '08/2022', '02/2008', '05/2023', '09/2018', '07/2017', '11/2019',
#        '04/2021', '08/2023', '05/2018', '10/2021', '09/2022', '08/2009',
#        '05/2020', '07/2018', '06/2010'], dtype=object)

# %%
def extract_month(dates):
    dates_series = pd.Series(dates)
    dates_series = pd.to_datetime(dates_series, errors='coerce')
    months = dates_series.dt.month
    return months

# %%
def extract_year(dates):
    dates_series = pd.Series(dates)
    dates_series = pd.to_datetime(dates_series, errors='coerce')
    year = dates_series.dt.year
    return year

# %%
data2['Month'] = extract_month(data2['Annee'])
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_20768\3126567526.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dates_series = pd.to_datetime(dates_series, errors='coerce')

# %%
data2['Year'] = extract_year(data2['Annee'])
# Out:
# C:\Users\abdel\AppData\Local\Temp\ipykernel_20768\39930126.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   dates_series = pd.to_datetime(dates_series, errors='coerce')

# %% [markdown]
# ###### 2 - 3.6 Options

# %%
for i in range(4) :
    print(data2['Options'][i])
# Out:
# 55 kW (75 CH) Boîte manuelle 1 248 cm³ 5 4 1 090 kg
# 350 kW (476 CH) Boîte automatique 1 2 254 kg
# 55 kW (75 CH) Boîte manuelle 1 390 cm³ 5 4 1 154 kg
# 73 kW (99 CH) Boîte manuelle 1 560 cm³ 5 4 1 145 kg

# %%
def extract_puissance(text):
    match = re.search(r'(\d{2,3})\s?kW', text)
    if match:
        return int(match.group(1))  # Convert to int
    return None

# Function to extract Transmission type (manual or automatic)
def extract_transmission(text):
    match = re.search(r'(Boîte .+?)\s(\d)', text)
    if match:
        return match.group(1)  # Return as string
    return None

def extract_cylindree(detail):
    # Extract the cubic centimeters value and remove any spaces or special characters
    match = re.search(r'(\d{1,3}(?:[ ,]\d{3})*)\s*cm³', detail)
    if match:
        # Convert to integer and remove any spaces within the number
        return int(match.group(1).replace(' ', '').replace(',', ''))
    return None

# Function to extract Vitesses (Number of gears)
def extract_vitesses(text):
    match = re.search(r'(\d)\s?(\d)', text)
    if match:
        return int(match.group(1))  # Convert to int
    return None

# Function to extract Cylindres (Number of cylinders)
def extract_weight(text):
    match = re.search(r'(\d+\s?\d+)\s?kg', text)
    if match:
        return int(match.group(1).replace('\u202f', '').replace(' ', ''))  # Remove special spaces and return as int
    return None

# %%
data2['Puissance'] = data2['Options'].apply(extract_puissance)
data2['TransmissionV2'] = data2['Options'].apply(extract_transmission)
data2['Cylindrée'] = data2['Options'].apply(extract_cylindree)
data2['Vitesses'] = data2['Options'].apply(extract_vitesses)
data2['Cylindres'] = data2['Options'].apply(extract_weight)

# %% [markdown]
# ###### 2 - 3.7 HorsePower

# %%
def extract_number_ch(text):
    match = re.search(r'\((\d+)\s*CH\)', text) 
    if match:
        return int(match.group(1))  
    return None

# %%
data2['HorsePower'] = data2['CarPuissance'].apply(extract_number_ch)

# %%
pd.set_option('display.max_columns', None)

# %%
data2['link'][0]
# Out:
# 'https://www.autoscout24.be/fr/offres/fiat-fiorino-1-3-multijet-bruit-moteur-export-marchand-diesel-rouge-25e19b4e-38d6-4999-9bf9-e414e95d392b'

# %%
data2
# Out:
#            CarName  carModele        CarPrice               Etat  Milieage  \
# 0             Fiat    Fiorino      € 1 450,-5      Très bon prix    250000
# 1             Audi  e-tron GT  € 59 950,-1, 5           Bon prix     27500
# 2       Volkswagen       Golf      € 4 000,-5      Très bon prix     73409
# 3          Citroen  C4 Cactus      € 6 450,-5      Très bon prix    142000
# 4             Audi  Q8 e-tron  € 68 950,-1, 5      Très bon prix     22700
# ..             ...        ...             ...                ...       ...
# 392  Mercedes-Benz    GLB 180  € 28 290,-1, 5  Pas d'information     31820
# 393           Audi        RS6     € 79 999,-5  Pas d'information    118226
# 394           Opel   Insignia  € 16 950,-1, 5      Très bon prix     86802
# 395        Renault     Megane     € 17 900,-5           Bon prix     50163
# 396          Volvo       XC40  € 27 995,-1, 5      Très bon prix     43968
#
#           Transmission    Annee           Carburant     CarPuissance  \
# 0       Boîte manuelle  03/2010              Diesel    55 kW (75 CH)
# 1               501 km  09/2021          Electrique  350 kW (476 CH)
# 2       Boîte manuelle  02/2006             Essence    55 kW (75 CH)
# 3       Boîte manuelle  07/2015              Diesel    73 kW (99 CH)
# 4               534 km  09/2023          Electrique  300 kW (408 CH)
# ..                 ...      ...                 ...              ...
# 392  Boîte automatique  11/2022             Essence  100 kW (136 CH)
# 393  Boîte automatique  09/2020             Essence  441 kW (600 CH)
# 394  Boîte automatique  08/2021              Diesel   90 kW (122 CH)
# 395  Boîte automatique  04/2021              Diesel   85 kW (116 CH)
# 396                  -  06/2020  Electrique/Essence  192 kW (261 CH)
#
#         CarVendeur  Portes  seats  \
# 0    Professionnel     5.0    5.0
# 1    Professionnel     5.0    4.0
# 2    Professionnel     5.0    3.0
# 3    Professionnel     5.0    5.0
# 4    Professionnel     5.0    5.0
# ..             ...     ...    ...
# 392  Professionnel     5.0    5.0
# 393  Professionnel     5.0    5.0
# 394  Professionnel     5.0    NaN
# 395  Professionnel     5.0    5.0
# 396  Professionnel     5.0    5.0
#
#                                                Options  \
# 0    55 kW (75 CH) Boîte manuelle 1 248 cm³ 5 4 1 0...
# 1        350 kW (476 CH) Boîte automatique 1 2 254 kg
# 2    55 kW (75 CH) Boîte manuelle 1 390 cm³ 5 4 1 1...
# 3    73 kW (99 CH) Boîte manuelle 1 560 cm³ 5 4 1 1...
# 4        300 kW (408 CH) Boîte automatique 1 2 585 kg
# ..                                                 ...
# 392     100 kW (136 CH) Boîte automatique 1 332 cm³ 1
# 393  441 kW (600 CH) Boîte automatique 3 996 cm³ 8 ...
# 394    90 kW (122 CH) Boîte automatique 1 496 cm³ 8 3
# 395  85 kW (116 CH) Boîte automatique 1 461 cm³ 7 4...
# 396                 192 kW (261 CH) Boîte automatique
#
#                                ConsommationEnergétique  \
# 0    Euro 4 Diesel 4,5 l/100 km (mixte) 123 g/km (m...
# 1            Électrique 501 km Incluse 0 g/km (comb.)
# 2    Euro 4 Essence 6,8 l/100 km (mixte) 166 g/km (...
# 3    Euro 6b Diesel 3,4 l/100 km (mixte) 90 g/km (m...
# 4            Électrique 534 km Incluse 0 g/km (comb.)
# ..                                                 ...
# 392                  Euro 6d Essence 159 g/km (mixte)
# 393  Euro 6d Essence 11,5 l/100 km (mixte) 263 g/km...
# 394  Euro 6 Diesel 4,1 l/100 km (mixte) 109 g/km (m...
# 395  Euro 6 Diesel 3,9 l/100 km (mixte) 104 g/km (m...
# 396                        Électrique 41 g/km (mixte)
#
#                             CouleurGarnissageIntérieur  \
# 0                                               Rouge
# 1    Gris Kemora Grey Pearl Effect Métallisé Gris C...
# 2                           Gris Métallisé Noir Tissu
# 3                           Gris Métallisé Noir Tissu
# 4       Noir Mythos Black Métallisé Noir Cuir partiel
# ..                                                 ...
# 392  Argent Iridium-silver, metallic paint Métallis...
# 393  Argent Floretzilver Metaalkleur. Métallisé Bru...
# 394                          Gris Métallisé Noir Cuir
# 395                        Noir Autres Noir Alcantara
# 396                                   Gris Gris Tissu
#
#                                                   link           fillcareName  \
# 0    https://www.autoscout24.be/fr/offres/fiat-fior...           FIAT-FIORINO
# 1    https://www.autoscout24.be/fr/offres/audi-e-tr...         AUDI-E-TRON GT
# 2    https://www.autoscout24.be/fr/offres/volkswage...        VOLKSWAGEN-GOLF
# 3    https://www.autoscout24.be/fr/offres/citroen-c...      CITROEN-C4 CACTUS
# 4    https://www.autoscout24.be/fr/offres/audi-q8-e...         AUDI-Q8 E-TRON
# ..                                                 ...                    ...
# 392  https://www.autoscout24.be/fr/offres/mercedes-...  MERCEDES-BENZ-GLB 180
# 393  https://www.autoscout24.be/fr/offres/audi-rs6-...               AUDI-RS6
# 394  https://www.autoscout24.be/fr/offres/opel-insi...          OPEL-INSIGNIA
# 395  https://www.autoscout24.be/fr/offres/renault-m...         RENAULT-MEGANE
# 396  https://www.autoscout24.be/fr/offres/volvo-xc4...             VOLVO-XC40
#
#       Price  etatCategory  Month    Year  Puissance     TransmissionV2  \
# 0      1450             3    3.0  2010.0         55     Boîte manuelle
# 1    599501             2    9.0  2021.0        350  Boîte automatique
# 2      4000             3    2.0  2006.0         55     Boîte manuelle
# 3      6450             3    7.0  2015.0         73     Boîte manuelle
# 4    689501             3    9.0  2023.0        300  Boîte automatique
# ..      ...           ...    ...     ...        ...                ...
# 392  282901             0   11.0  2022.0        100  Boîte automatique
# 393   79999             0    9.0  2020.0        441  Boîte automatique
# 394  169501             3    8.0  2021.0         90  Boîte automatique
# 395   17900             2    4.0  2021.0         85  Boîte automatique
# 396  279951             3    6.0  2020.0        192               None
#
#      Cylindrée  Vitesses  Cylindres  HorsePower
# 0       1248.0         5     1090.0          75
# 1          NaN         3     2254.0         476
# 2       1390.0         5     1154.0          75
# 3       1560.0         7     1145.0          99
# 4          NaN         3     2585.0         408
# ..         ...       ...        ...         ...
# 392     1332.0         1        NaN         136
# 393     3996.0         4     2150.0         600
# 394     1496.0         9        NaN         122
# 395     1461.0         8     1422.0         116
# 396        NaN         1        NaN         261
#
# [397 rows x 27 columns]

# %%
data2
# Out:
#            CarName  carModele        CarPrice               Etat  Milieage  \
# 0             Fiat    Fiorino      € 1 450,-5      Très bon prix    250000
# 1             Audi  e-tron GT  € 59 950,-1, 5           Bon prix     27500
# 2       Volkswagen       Golf      € 4 000,-5      Très bon prix     73409
# 3          Citroen  C4 Cactus      € 6 450,-5      Très bon prix    142000
# 4             Audi  Q8 e-tron  € 68 950,-1, 5      Très bon prix     22700
# ..             ...        ...             ...                ...       ...
# 392  Mercedes-Benz    GLB 180  € 28 290,-1, 5  Pas d'information     31820
# 393           Audi        RS6     € 79 999,-5  Pas d'information    118226
# 394           Opel   Insignia  € 16 950,-1, 5      Très bon prix     86802
# 395        Renault     Megane     € 17 900,-5           Bon prix     50163
# 396          Volvo       XC40  € 27 995,-1, 5      Très bon prix     43968
#
#           Transmission    Annee           Carburant     CarPuissance  \
# 0       Boîte manuelle  03/2010              Diesel    55 kW (75 CH)
# 1               501 km  09/2021          Electrique  350 kW (476 CH)
# 2       Boîte manuelle  02/2006             Essence    55 kW (75 CH)
# 3       Boîte manuelle  07/2015              Diesel    73 kW (99 CH)
# 4               534 km  09/2023          Electrique  300 kW (408 CH)
# ..                 ...      ...                 ...              ...
# 392  Boîte automatique  11/2022             Essence  100 kW (136 CH)
# 393  Boîte automatique  09/2020             Essence  441 kW (600 CH)
# 394  Boîte automatique  08/2021              Diesel   90 kW (122 CH)
# 395  Boîte automatique  04/2021              Diesel   85 kW (116 CH)
# 396                  -  06/2020  Electrique/Essence  192 kW (261 CH)
#
#         CarVendeur  Portes  seats  \
# 0    Professionnel     5.0    5.0
# 1    Professionnel     5.0    4.0
# 2    Professionnel     5.0    3.0
# 3    Professionnel     5.0    5.0
# 4    Professionnel     5.0    5.0
# ..             ...     ...    ...
# 392  Professionnel     5.0    5.0
# 393  Professionnel     5.0    5.0
# 394  Professionnel     5.0    NaN
# 395  Professionnel     5.0    5.0
# 396  Professionnel     5.0    5.0
#
#                                                Options  \
# 0    55 kW (75 CH) Boîte manuelle 1 248 cm³ 5 4 1 0...
# 1        350 kW (476 CH) Boîte automatique 1 2 254 kg
# 2    55 kW (75 CH) Boîte manuelle 1 390 cm³ 5 4 1 1...
# 3    73 kW (99 CH) Boîte manuelle 1 560 cm³ 5 4 1 1...
# 4        300 kW (408 CH) Boîte automatique 1 2 585 kg
# ..                                                 ...
# 392     100 kW (136 CH) Boîte automatique 1 332 cm³ 1
# 393  441 kW (600 CH) Boîte automatique 3 996 cm³ 8 ...
# 394    90 kW (122 CH) Boîte automatique 1 496 cm³ 8 3
# 395  85 kW (116 CH) Boîte automatique 1 461 cm³ 7 4...
# 396                 192 kW (261 CH) Boîte automatique
#
#                                ConsommationEnergétique  \
# 0    Euro 4 Diesel 4,5 l/100 km (mixte) 123 g/km (m...
# 1            Électrique 501 km Incluse 0 g/km (comb.)
# 2    Euro 4 Essence 6,8 l/100 km (mixte) 166 g/km (...
# 3    Euro 6b Diesel 3,4 l/100 km (mixte) 90 g/km (m...
# 4            Électrique 534 km Incluse 0 g/km (comb.)
# ..                                                 ...
# 392                  Euro 6d Essence 159 g/km (mixte)
# 393  Euro 6d Essence 11,5 l/100 km (mixte) 263 g/km...
# 394  Euro 6 Diesel 4,1 l/100 km (mixte) 109 g/km (m...
# 395  Euro 6 Diesel 3,9 l/100 km (mixte) 104 g/km (m...
# 396                        Électrique 41 g/km (mixte)
#
#                             CouleurGarnissageIntérieur  \
# 0                                               Rouge
# 1    Gris Kemora Grey Pearl Effect Métallisé Gris C...
# 2                           Gris Métallisé Noir Tissu
# 3                           Gris Métallisé Noir Tissu
# 4       Noir Mythos Black Métallisé Noir Cuir partiel
# ..                                                 ...
# 392  Argent Iridium-silver, metallic paint Métallis...
# 393  Argent Floretzilver Metaalkleur. Métallisé Bru...
# 394                          Gris Métallisé Noir Cuir
# 395                        Noir Autres Noir Alcantara
# 396                                   Gris Gris Tissu
#
#                                                   link           fillcareName  \
# 0    https://www.autoscout24.be/fr/offres/fiat-fior...           FIAT-FIORINO
# 1    https://www.autoscout24.be/fr/offres/audi-e-tr...         AUDI-E-TRON GT
# 2    https://www.autoscout24.be/fr/offres/volkswage...        VOLKSWAGEN-GOLF
# 3    https://www.autoscout24.be/fr/offres/citroen-c...      CITROEN-C4 CACTUS
# 4    https://www.autoscout24.be/fr/offres/audi-q8-e...         AUDI-Q8 E-TRON
# ..                                                 ...                    ...
# 392  https://www.autoscout24.be/fr/offres/mercedes-...  MERCEDES-BENZ-GLB 180
# 393  https://www.autoscout24.be/fr/offres/audi-rs6-...               AUDI-RS6
# 394  https://www.autoscout24.be/fr/offres/opel-insi...          OPEL-INSIGNIA
# 395  https://www.autoscout24.be/fr/offres/renault-m...         RENAULT-MEGANE
# 396  https://www.autoscout24.be/fr/offres/volvo-xc4...             VOLVO-XC40
#
#       Price  etatCategory  Month    Year  Puissance     TransmissionV2  \
# 0      1450             3    3.0  2010.0         55     Boîte manuelle
# 1    599501             2    9.0  2021.0        350  Boîte automatique
# 2      4000             3    2.0  2006.0         55     Boîte manuelle
# 3      6450             3    7.0  2015.0         73     Boîte manuelle
# 4    689501             3    9.0  2023.0        300  Boîte automatique
# ..      ...           ...    ...     ...        ...                ...
# 392  282901             0   11.0  2022.0        100  Boîte automatique
# 393   79999             0    9.0  2020.0        441  Boîte automatique
# 394  169501             3    8.0  2021.0         90  Boîte automatique
# 395   17900             2    4.0  2021.0         85  Boîte automatique
# 396  279951             3    6.0  2020.0        192               None
#
#      Cylindrée  Vitesses  Cylindres  HorsePower
# 0       1248.0         5     1090.0          75
# 1          NaN         3     2254.0         476
# 2       1390.0         5     1154.0          75
# 3       1560.0         7     1145.0          99
# 4          NaN         3     2585.0         408
# ..         ...       ...        ...         ...
# 392     1332.0         1        NaN         136
# 393     3996.0         4     2150.0         600
# 394     1496.0         9        NaN         122
# 395     1461.0         8     1422.0         116
# 396        NaN         1        NaN         261
#
# [397 rows x 27 columns]

# %%
def extract_emission_class(text):
    match = re.search(r'(Euro \d+[a-z]*)', text)
    return match.group(1) if match else None

def extract_fuel_type(text):
    match = re.search(r'(Diesel|Essence|Électrique)', text, re.IGNORECASE)
    return match.group(1) if match else None

def extract_fuel_consumption(text):
    match = re.search(r'(\d+,?\d*) l/100 km', text)
    return match.group(1).replace(',', '.') if match else None

def extract_co2_emissions(text):
    match = re.search(r'(\d+) g/km', text)
    return int(match.group(1)) if match else None

# %%
data2["ClasseEmission"] = data2['ConsommationEnergétique'].apply(extract_emission_class)
data2["Typedecarburant"] = data2['ConsommationEnergétique'].apply(extract_fuel_type)
data2["Consommationdecarburant"] = data2['ConsommationEnergétique'].apply(extract_fuel_consumption)
data2["ÉmissionsdeCO2"] = data2['ConsommationEnergétique'].apply(extract_co2_emissions)

# %%
data2
# Out:
#            CarName  carModele        CarPrice               Etat  Milieage  \
# 0             Fiat    Fiorino      € 1 450,-5      Très bon prix    250000
# 1             Audi  e-tron GT  € 59 950,-1, 5           Bon prix     27500
# 2       Volkswagen       Golf      € 4 000,-5      Très bon prix     73409
# 3          Citroen  C4 Cactus      € 6 450,-5      Très bon prix    142000
# 4             Audi  Q8 e-tron  € 68 950,-1, 5      Très bon prix     22700
# ..             ...        ...             ...                ...       ...
# 392  Mercedes-Benz    GLB 180  € 28 290,-1, 5  Pas d'information     31820
# 393           Audi        RS6     € 79 999,-5  Pas d'information    118226
# 394           Opel   Insignia  € 16 950,-1, 5      Très bon prix     86802
# 395        Renault     Megane     € 17 900,-5           Bon prix     50163
# 396          Volvo       XC40  € 27 995,-1, 5      Très bon prix     43968
#
#           Transmission    Annee           Carburant     CarPuissance  \
# 0       Boîte manuelle  03/2010              Diesel    55 kW (75 CH)
# 1               501 km  09/2021          Electrique  350 kW (476 CH)
# 2       Boîte manuelle  02/2006             Essence    55 kW (75 CH)
# 3       Boîte manuelle  07/2015              Diesel    73 kW (99 CH)
# 4               534 km  09/2023          Electrique  300 kW (408 CH)
# ..                 ...      ...                 ...              ...
# 392  Boîte automatique  11/2022             Essence  100 kW (136 CH)
# 393  Boîte automatique  09/2020             Essence  441 kW (600 CH)
# 394  Boîte automatique  08/2021              Diesel   90 kW (122 CH)
# 395  Boîte automatique  04/2021              Diesel   85 kW (116 CH)
# 396                  -  06/2020  Electrique/Essence  192 kW (261 CH)
#
#         CarVendeur  Portes  seats  \
# 0    Professionnel     5.0    5.0
# 1    Professionnel     5.0    4.0
# 2    Professionnel     5.0    3.0
# 3    Professionnel     5.0    5.0
# 4    Professionnel     5.0    5.0
# ..             ...     ...    ...
# 392  Professionnel     5.0    5.0
# 393  Professionnel     5.0    5.0
# 394  Professionnel     5.0    NaN
# 395  Professionnel     5.0    5.0
# 396  Professionnel     5.0    5.0
#
#                                                Options  \
# 0    55 kW (75 CH) Boîte manuelle 1 248 cm³ 5 4 1 0...
# 1        350 kW (476 CH) Boîte automatique 1 2 254 kg
# 2    55 kW (75 CH) Boîte manuelle 1 390 cm³ 5 4 1 1...
# 3    73 kW (99 CH) Boîte manuelle 1 560 cm³ 5 4 1 1...
# 4        300 kW (408 CH) Boîte automatique 1 2 585 kg
# ..                                                 ...
# 392     100 kW (136 CH) Boîte automatique 1 332 cm³ 1
# 393  441 kW (600 CH) Boîte automatique 3 996 cm³ 8 ...
# 394    90 kW (122 CH) Boîte automatique 1 496 cm³ 8 3
# 395  85 kW (116 CH) Boîte automatique 1 461 cm³ 7 4...
# 396                 192 kW (261 CH) Boîte automatique
#
#                                ConsommationEnergétique  \
# 0    Euro 4 Diesel 4,5 l/100 km (mixte) 123 g/km (m...
# 1            Électrique 501 km Incluse 0 g/km (comb.)
# 2    Euro 4 Essence 6,8 l/100 km (mixte) 166 g/km (...
# 3    Euro 6b Diesel 3,4 l/100 km (mixte) 90 g/km (m...
# 4            Électrique 534 km Incluse 0 g/km (comb.)
# ..                                                 ...
# 392                  Euro 6d Essence 159 g/km (mixte)
# 393  Euro 6d Essence 11,5 l/100 km (mixte) 263 g/km...
# 394  Euro 6 Diesel 4,1 l/100 km (mixte) 109 g/km (m...
# 395  Euro 6 Diesel 3,9 l/100 km (mixte) 104 g/km (m...
# 396                        Électrique 41 g/km (mixte)
#
#                             CouleurGarnissageIntérieur  \
# 0                                               Rouge
# 1    Gris Kemora Grey Pearl Effect Métallisé Gris C...
# 2                           Gris Métallisé Noir Tissu
# 3                           Gris Métallisé Noir Tissu
# 4       Noir Mythos Black Métallisé Noir Cuir partiel
# ..                                                 ...
# 392  Argent Iridium-silver, metallic paint Métallis...
# 393  Argent Floretzilver Metaalkleur. Métallisé Bru...
# 394                          Gris Métallisé Noir Cuir
# 395                        Noir Autres Noir Alcantara
# 396                                   Gris Gris Tissu
#
#                                                   link           fillcareName  \
# 0    https://www.autoscout24.be/fr/offres/fiat-fior...           FIAT-FIORINO
# 1    https://www.autoscout24.be/fr/offres/audi-e-tr...         AUDI-E-TRON GT
# 2    https://www.autoscout24.be/fr/offres/volkswage...        VOLKSWAGEN-GOLF
# 3    https://www.autoscout24.be/fr/offres/citroen-c...      CITROEN-C4 CACTUS
# 4    https://www.autoscout24.be/fr/offres/audi-q8-e...         AUDI-Q8 E-TRON
# ..                                                 ...                    ...
# 392  https://www.autoscout24.be/fr/offres/mercedes-...  MERCEDES-BENZ-GLB 180
# 393  https://www.autoscout24.be/fr/offres/audi-rs6-...               AUDI-RS6
# 394  https://www.autoscout24.be/fr/offres/opel-insi...          OPEL-INSIGNIA
# 395  https://www.autoscout24.be/fr/offres/renault-m...         RENAULT-MEGANE
# 396  https://www.autoscout24.be/fr/offres/volvo-xc4...             VOLVO-XC40
#
#       Price  etatCategory  Month    Year  Puissance     TransmissionV2  \
# 0      1450             3    3.0  2010.0         55     Boîte manuelle
# 1    599501             2    9.0  2021.0        350  Boîte automatique
# 2      4000             3    2.0  2006.0         55     Boîte manuelle
# 3      6450             3    7.0  2015.0         73     Boîte manuelle
# 4    689501             3    9.0  2023.0        300  Boîte automatique
# ..      ...           ...    ...     ...        ...                ...
# 392  282901             0   11.0  2022.0        100  Boîte automatique
# 393   79999             0    9.0  2020.0        441  Boîte automatique
# 394  169501             3    8.0  2021.0         90  Boîte automatique
# 395   17900             2    4.0  2021.0         85  Boîte automatique
# 396  279951             3    6.0  2020.0        192               None
#
#      Cylindrée  Vitesses  Cylindres  HorsePower ClasseEmission  \
# 0       1248.0         5     1090.0          75         Euro 4
# 1          NaN         3     2254.0         476           None
# 2       1390.0         5     1154.0          75         Euro 4
# 3       1560.0         7     1145.0          99        Euro 6b
# 4          NaN         3     2585.0         408           None
# ..         ...       ...        ...         ...            ...
# 392     1332.0         1        NaN         136        Euro 6d
# 393     3996.0         4     2150.0         600        Euro 6d
# 394     1496.0         9        NaN         122         Euro 6
# 395     1461.0         8     1422.0         116         Euro 6
# 396        NaN         1        NaN         261           None
#
#     Typedecarburant Consommationdecarburant  ÉmissionsdeCO2
# 0            Diesel                     4.5           123.0
# 1        Électrique                    None             0.0
# 2           Essence                     6.8           166.0
# 3            Diesel                     3.4            90.0
# 4        Électrique                    None             0.0
# ..              ...                     ...             ...
# 392         Essence                    None           159.0
# 393         Essence                    11.5           263.0
# 394          Diesel                     4.1           109.0
# 395          Diesel                     3.9           104.0
# 396      Électrique                    None            41.0
#
# [397 rows x 31 columns]

# %%
data2.drop(["CarName", "carModele", "CarPrice","Annee", "CarPuissance", "Options", "link", "CouleurGarnissageIntérieur", "ConsommationEnergétique", "Transmission"], axis = 1, inplace=True)

# %%
data2.columns
# Out:
# Index(['Etat', 'Milieage', 'Carburant', 'CarVendeur', 'Portes', 'seats',
#        'fillcareName', 'Price', 'etatCategory', 'Month', 'Year', 'Puissance',
#        'TransmissionV2', 'Cylindrée', 'Vitesses', 'Cylindres', 'HorsePower',
#        'ClasseEmission', 'Typedecarburant', 'Consommationdecarburant',
#        'ÉmissionsdeCO2'],
#       dtype='object')

# %%
data2
# Out:
#                   Etat  Milieage           Carburant     CarVendeur  Portes  \
# 0        Très bon prix    250000              Diesel  Professionnel     5.0
# 1             Bon prix     27500          Electrique  Professionnel     5.0
# 2        Très bon prix     73409             Essence  Professionnel     5.0
# 3        Très bon prix    142000              Diesel  Professionnel     5.0
# 4        Très bon prix     22700          Electrique  Professionnel     5.0
# ..                 ...       ...                 ...            ...     ...
# 392  Pas d'information     31820             Essence  Professionnel     5.0
# 393  Pas d'information    118226             Essence  Professionnel     5.0
# 394      Très bon prix     86802              Diesel  Professionnel     5.0
# 395           Bon prix     50163              Diesel  Professionnel     5.0
# 396      Très bon prix     43968  Electrique/Essence  Professionnel     5.0
#
#      seats           fillcareName   Price  etatCategory  Month    Year  \
# 0      5.0           FIAT-FIORINO    1450             3    3.0  2010.0
# 1      4.0         AUDI-E-TRON GT  599501             2    9.0  2021.0
# 2      3.0        VOLKSWAGEN-GOLF    4000             3    2.0  2006.0
# 3      5.0      CITROEN-C4 CACTUS    6450             3    7.0  2015.0
# 4      5.0         AUDI-Q8 E-TRON  689501             3    9.0  2023.0
# ..     ...                    ...     ...           ...    ...     ...
# 392    5.0  MERCEDES-BENZ-GLB 180  282901             0   11.0  2022.0
# 393    5.0               AUDI-RS6   79999             0    9.0  2020.0
# 394    NaN          OPEL-INSIGNIA  169501             3    8.0  2021.0
# 395    5.0         RENAULT-MEGANE   17900             2    4.0  2021.0
# 396    5.0             VOLVO-XC40  279951             3    6.0  2020.0
#
#      Puissance     TransmissionV2  Cylindrée  Vitesses  Cylindres  HorsePower  \
# 0           55     Boîte manuelle     1248.0         5     1090.0          75
# 1          350  Boîte automatique        NaN         3     2254.0         476
# 2           55     Boîte manuelle     1390.0         5     1154.0          75
# 3           73     Boîte manuelle     1560.0         7     1145.0          99
# 4          300  Boîte automatique        NaN         3     2585.0         408
# ..         ...                ...        ...       ...        ...         ...
# 392        100  Boîte automatique     1332.0         1        NaN         136
# 393        441  Boîte automatique     3996.0         4     2150.0         600
# 394         90  Boîte automatique     1496.0         9        NaN         122
# 395         85  Boîte automatique     1461.0         8     1422.0         116
# 396        192               None        NaN         1        NaN         261
#
#     ClasseEmission Typedecarburant Consommationdecarburant  ÉmissionsdeCO2
# 0           Euro 4          Diesel                     4.5           123.0
# 1             None      Électrique                    None             0.0
# 2           Euro 4         Essence                     6.8           166.0
# 3          Euro 6b          Diesel                     3.4            90.0
# 4             None      Électrique                    None             0.0
# ..             ...             ...                     ...             ...
# 392        Euro 6d         Essence                    None           159.0
# 393        Euro 6d         Essence                    11.5           263.0
# 394         Euro 6          Diesel                     4.1           109.0
# 395         Euro 6          Diesel                     3.9           104.0
# 396           None      Électrique                    None            41.0
#
# [397 rows x 21 columns]

# %% [markdown]
# #### Save the clean data

# %%
print(os.getcwd())
# Out:
# C:\Users\abdel\OneDrive\Bureau\CarBrain\CARBRAIN\notebook

# %%
from path import PATH_PROCESSED_CSV 
import csv

# %%
data2.to_csv(PATH_PROCESSED_CSV, index=False, encoding='utf-8')
